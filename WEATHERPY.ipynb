# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

from random import uniform
from citipy import citipy
from config import api_key

import openweathermapy.core as owm
import csv
import urllib
import time

# %%
import openweathermapy.core as owm


from config import api_key

url = "http://api.openweathermap.org/data/2.5/forecast" \
        "?APPID=" + api_key
    
units = "Imperial"
settings = {"units": units, "appid" :api_key}

# %%
cities = []
while (len(cities) < 700):
    lat, lon = rnd.uniform(-180,180), rnd.uniform(-90, 90)
    city = citipy.nearest_city(lat, lon)
    if (city not in cities):
        cities.append(city)
for i in (range(700)):
    print(cities[i].city_name)
# Out:
# busselton
# laguna
# illoqqortoormiut
# bredasdorp
# jamestown
# barentsburg
# dikson
# albany
# ushuaia
# awbari
# longyearbyen
# vologda
# taolanaro
# mocuba
# belushya guba
# port elizabeth
# thinadhoo
# kilindoni
# okakarara
# nanortalik
# lebu
# leshukonskoye
# tasiilaq
# attawapiskat
# saint-philippe
# ghanzi
# sao filipe
# cruzeiro do sul
# matara
# adrar
# marau
# beira
# qaanaaq
# narsaq
# la asuncion
# sicula
# upernavik
# mahebourg
# ancud
# port alfred
# hermanus
# pisco
# georgetown
# oriximina
# moose factory
# porto walter
# umm lajj
# amderma
# kristiansund
# bahia honda
# ponta do sol
# cape town
# murgab
# tarudant
# punta arenas
# korla
# itarema
# hithadhoo
# iqaluit
# bambous virieux
# dubai
# mandiana
# kruisfontein
# taltal
# east london
# cocachacra
# svencioneliai
# niksar
# hofn
# benghazi
# kasongo-lunda
# salisbury
# bathsheba
# karkaralinsk
# montoro
# bengkulu
# maragogi
# meulaboh
# chuy
# planadas
# akdepe
# pangoa
# salalah
# kiruna
# oistins
# apomu
# ...

# %%
query_url = f"{url}&units={units}&q="


city_weather = []

i = 0

for city in cities:
    i = i + 1
    weather_dict = {}
    print ("Processing Record", i, "of Set 1 | " + city.city_name)
    final_url = query_url + city.city_name
    print (final_url)
   
    response = requests.get(final_url).json()
    if response['cod'] == "200":
        weather_dict["city"] = response['city']['name']
        weather_dict["cloudiness"] = response['list'][0]['clouds']['all']
        weather_dict["country"] = response['city']['country']
        weather_dict["date"] = response['list'][0]['dt']
        weather_dict["humidity"] = response['list'][0]['main']['humidity']
        weather_dict["lat"] = response['city']['coord']['lat']
        weather_dict["lng"] = response['city']['coord']['lon']
        weather_dict["max temp"] = response['list'][0]['main']['temp_max']
        weather_dict["wind speed"] = response['list'][0]['wind']['speed']
        city_weather.append(weather_dict)
# Out:
# Processing Record 1 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=busselton
# Processing Record 2 of Set 1 | laguna
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=laguna
# Processing Record 3 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=illoqqortoormiut
# Processing Record 4 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=bredasdorp
# Processing Record 5 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=jamestown
# Processing Record 6 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/forecast?APPID=979ecc09a4ea7cab917ef0fefc957a6c&units=Imperial&q=barentsburg
# ...

# %%
city_weather_df = pd.DataFrame(city_weather).head(500)

city_weather_df
# Out:
#                  city  cloudiness country        date  humidity      lat  \
# 0           Busselton           0      AU  1521774000        98 -33.6445
# 1              Laguna          88      MX  1521774000        40  27.5185
# 2          Bredasdorp           0      ZA  1521774000        96 -34.5331
# 3           Jamestown           0      AU  1521774000        79 -33.2075
# 4              Dikson          44      RU  1521774000        86  73.5069
# 5              Albany          80      US  1521774000        70  42.6512
# 6             Ushuaia           0      AR  1521774000        98 -54.8070
# 7              Awbari           0      LY  1521774000        35  26.5897
# 8        Longyearbyen          20      NO  1521774000        85  78.2198
# 9             Vologda          88      RU  1521774000        92  59.2189
# 10             Mocuba          92      MZ  1521774000        97 -16.8393
# 11     Port Elizabeth          76      US  1521774000        81  39.3134
# ...

# %%
# Your objective is to build a series of scatter plots to showcase the following relationships:

# Temperature (F) vs. Latitude
# Humidity (%) vs. Latitude
# Cloudiness (%) vs. Latitude
# Wind Speed (mph) vs. Latitude

# Build a scatter plot for each data type
plt.scatter(city_weather_df["max temp"], 
            city_weather_df["lat"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Zip Codes")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (01/05/17)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather_df["humidity"], 
            city_weather_df["lat"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Zip Codes")

# Incorporate the other graph properties
plt.xlim(-90, 90)
plt.title("City Latitude vs. Humidity (01/05/17)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather_df["cloudiness"], 
            city_weather_df["lat"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Zip Codes")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (01/05/17)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather_df["wind speed"], 
            city_weather_df["lat"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Zip Codes")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (01/05/17)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()
